# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import re

# %%
XF = pd.read_csv("00_Stacked_Dataframe.csv")

# %% [markdown]
# #### Only Considering Stations within Washington DC Boundary

# %%
Station_shp = pd.read_csv("./XX_Processed_Data/A0_WashingtonDC_StationIDs_01.csv")

# %%
XF.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'Hour_(Starting)', 'Year', 'StationID_YearHour'],
#       dtype='object')

# %%
Station_shp.columns
# Out:
# Index(['start_station', 'Station_ID', 'start_lat', 'start_lng', 'Neighb_Cls',
#        'Ward'],
#       dtype='object')

# %% [markdown]
# ### Adding Season Column

# %%
# Convert the column to datetime
XF['started_at'] = pd.to_datetime(XF['started_at'], format='%Y-%m-%d %H:%M:%S')
XF['ended_at'] = pd.to_datetime(XF['ended_at'], format='%Y-%m-%d %H:%M:%S')

# %%
filt = (XF["started_at"].dt.month >= 3) & (XF['started_at'].dt.month <= 5)
XF.loc[filt,"Season"] = "Spring"

# %%
filt = (XF["started_at"].dt.month >= 6) & (XF['started_at'].dt.month <= 8)
XF.loc[filt,"Season"] = "Summer"

# %%
filt = (XF["started_at"].dt.month >= 9) & (XF['started_at'].dt.month <= 11)
XF.loc[filt,"Season"] = "Fall"

# %%
filt1 = (XF["started_at"].dt.month >= 2)
filt2 = (XF['started_at'].dt.month == 12)
filt = filt1 & filt2

XF.loc[filt,"Season"] = "Winter"

# %%
XF["Season"] = XF["Season"].fillna("Winter")

# %%
XF["Station_ID"] = XF["start_station_id"]

# %%
# Define a function to label each date as weekday or weekend
def categorize_weekday_or_weekend(date):
    if date.weekday() < 5:  # 0-4 represent Monday to Friday (weekdays)
        return 'Weekday'
    else:
        return 'Weekend'

# Apply the function to create a new column 'Day_Type'
XF['Day_Type'] = XF['started_at'].apply(categorize_weekday_or_weekend)

# %%
# Merge the DataFrames based on the common fields 'ID'
merged_df = pd.merge(XF, Station_shp, on='Station_ID')

# %%
merged_df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat_x', 'start_lng_x', 'end_lat', 'end_lng',
#        'member_casual', 'Hour_(Starting)', 'Year', 'StationID_YearHour',
#        'Season', 'Station_ID', 'Day_Type', 'start_station', 'start_lat_y',
#        'start_lng_y', 'Neighb_Cls', 'Ward'],
#       dtype='object')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6128884 entries, 0 to 6128883
# Data columns (total 24 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   started_at          datetime64[ns]
#  3   ended_at            datetime64[ns]
#  4   start_station_name  object
#  5   start_station_id    int64
#  6   end_station_name    object
#  7   end_station_id      int64
#  8   start_lat_x         float64
#  9   start_lng_x         float64
#  10  end_lat             float64
#  11  end_lng             float64
#  12  member_casual       object
#  13  Hour_(Starting)     int64
#  14  Year                int64
#  15  StationID_YearHour  object
#  16  Season              object
#  17  Station_ID          int64
#  18  Day_Type            object
#  19  start_station       object
#  20  start_lat_y         float64
#  21  start_lng_y         float64
#  22  Neighb_Cls          object
#  23  Ward                object
# dtypes: datetime64[ns](2), float64(6), int64(5), object(11)
# memory usage: 1.1+ GB

# %%
merged_df['end_station_id'] = (merged_df['end_station_id'].astype(int)).astype(str)

# %%
merged_df['End_StationID_YearHour_Month'] = merged_df['end_station_id'] + "_" + merged_df['Year'].astype(str) + "_" + merged_df['Hour_(Starting)'].astype(str) + "_" + merged_df["started_at"].dt.month.astype(str) + "_" + merged_df["Day_Type"]
merged_df["Start_StationID_YearHour_Month"] = merged_df["StationID_YearHour"] + "_" + merged_df["started_at"].dt.month.astype(str) + "_" + merged_df["Day_Type"]

# %%
merged_df['Start_StationID_YearHour_Month']
# Out:
# 0          31660_2021_21_7_Weekend
# 1          31660_2021_16_7_Weekend
# 2          31660_2021_21_7_Weekend
# 3          31660_2021_19_7_Weekday
# 4          31660_2021_19_7_Weekend
#                     ...
# 6128879    31426_2023_21_7_Weekday
# 6128880    31426_2023_21_7_Weekday
# 6128881    31426_2023_11_7_Weekday
# 6128882     31426_2023_8_7_Weekday
# 6128883    31426_2023_11_7_Weekday
# Name: Start_StationID_YearHour_Month, Length: 6128884, dtype: object

# %% [markdown]
# ## 1.0 Master csv File Development

# %%
filt1 = merged_df["started_at"].dt.hour == 23
# filt2 = merged_df["Year"] == 2021

x = merged_df[ filt1 ]
Start_Stats = x["Start_StationID_YearHour_Month"].value_counts()
End_Stats = x['End_StationID_YearHour_Month'].value_counts()

Start_DF = pd.DataFrame(Start_Stats)
End_DF = pd.DataFrame(End_Stats)

# %%
End_DF

End_DF = End_DF.reset_index()
# y["Count"] =  y["StationID_YearHour"]


End_DF.rename(columns = {"End_StationID_YearHour_Month": "Arrival Count"}, inplace=True)
# y.drop(columns = {"StationID_YearHour"}, inplace=True)
End_DF
# Out:
#                           index  Arrival Count
# 0       31627_2023_23_7_Weekday             72
# 1       31241_2022_23_9_Weekday             70
# 2       31330_2022_23_9_Weekday             68
# 3       31266_2021_23_8_Weekday             68
# 4       31247_2021_23_7_Weekday             68
# ...                         ...            ...
# 14299  31637_2022_23_11_Weekend              1
# 14300   31826_2023_23_7_Weekday              1
# 14301  31806_2022_23_12_Weekday              1
# 14302   31801_2023_23_5_Weekend              1
# 14303   31936_2023_23_4_Weekday              1
#
# [14304 rows x 2 columns]

# %%
Start_DF = Start_DF.reset_index()
# y["Count"] =  y["StationID_YearHour"]


Start_DF.rename(columns = {"Start_StationID_YearHour_Month": "Deperture Count"}, inplace=True)
# y.drop(columns = {"StationID_YearHour"}, inplace=True)
Start_DF
# Out:
#                          index  Deperture Count
# 0      31609_2023_23_5_Weekday              138
# 1      31114_2023_23_6_Weekday              104
# 2      31209_2022_23_8_Weekday               99
# 3      31203_2023_23_5_Weekday               95
# 4      31609_2022_23_6_Weekday               91
# ...                        ...              ...
# 12632  31417_2023_23_5_Weekend                1
# 12633  31417_2023_23_3_Weekday                1
# 12634  31417_2023_23_3_Weekend                1
# 12635  31417_2023_23_2_Weekday                1
# 12636  31421_2023_23_6_Weekend                1
#
# [12637 rows x 2 columns]

# %%
# Merge the DataFrames based on the common fields 'ID'
Start_End_XX = pd.merge(Start_DF, End_DF, on='index')

# %%
# Concatenate df2 under df1
Start_End_DF = pd.concat([Start_End_DF, Start_End_XX], ignore_index=True)

# %%
Start_End_DF
# Out:
#                           index  Deperture Count  Arrival Count
# 0        31114_2022_0_8_Weekend               86             26
# 1        31114_2023_0_5_Weekend               81             25
# 2        31114_2021_0_7_Weekend               81             34
# 3       31114_2021_0_10_Weekend               75             36
# 4        31114_2023_0_4_Weekend               74             30
# ...                         ...              ...            ...
# 279251  31417_2023_23_5_Weekend                1              2
# 279252  31417_2023_23_3_Weekday                1              7
# 279253  31417_2023_23_3_Weekend                1              3
# 279254  31417_2023_23_2_Weekday                1              3
# 279255  31421_2023_23_6_Weekend                1              3
#
# [279256 rows x 3 columns]

# %%
Start_End_DF[['StationID', 'Year', 'Hour', 'Month', "Day_Type"]] = Start_End_DF['index'].str.split('_', expand=True)
Start_End_DF.drop(columns = ["index"] )
# Out:
#         Deperture Count  Arrival Count StationID  Year Hour Month Day_Type
# 0                    86             26     31114  2022    0     8  Weekend
# 1                    81             25     31114  2023    0     5  Weekend
# 2                    81             34     31114  2021    0     7  Weekend
# 3                    75             36     31114  2021    0    10  Weekend
# 4                    74             30     31114  2023    0     4  Weekend
# ...                 ...            ...       ...   ...  ...   ...      ...
# 279251                1              2     31417  2023   23     5  Weekend
# 279252                1              7     31417  2023   23     3  Weekday
# 279253                1              3     31417  2023   23     3  Weekend
# 279254                1              3     31417  2023   23     2  Weekday
# 279255                1              3     31421  2023   23     6  Weekend
#
# [279256 rows x 7 columns]

# %%
len(Start_End_DF["StationID"].unique())
# Out:
# 359

# %%
Start_End_DF.drop(columns = ["index"], inplace = True)

# %%
Station_shp["StationID"] = Station_shp["Station_ID"].astype(str)

# %%
# Merge the DataFrames based on the common fields 'ID'
Merged_Start_End_DF = pd.merge(Start_End_DF, Station_shp, on='StationID')

# %%
Merged_Start_End_DF.head()
# Out:
#    Deperture Count  Arrival Count StationID  Year Hour Month Day_Type  \
# 0               86             26     31114  2022    0     8  Weekend
# 1               81             25     31114  2023    0     5  Weekend
# 2               81             34     31114  2021    0     7  Weekend
# 3               75             36     31114  2021    0    10  Weekend
# 4               74             30     31114  2023    0     4  Weekend
#
#               start_station  Station_ID  start_lat  start_lng Neighb_Cls  \
# 0  18th St & Wyoming Ave NW       31114  38.918809 -77.041571  Cluster 1
# 1  18th St & Wyoming Ave NW       31114  38.918809 -77.041571  Cluster 1
# 2  18th St & Wyoming Ave NW       31114  38.918809 -77.041571  Cluster 1
# 3  18th St & Wyoming Ave NW       31114  38.918809 -77.041571  Cluster 1
# 4  18th St & Wyoming Ave NW       31114  38.918809 -77.041571  Cluster 1
#
#      Ward
# 0  Ward 1
# 1  Ward 1
# 2  Ward 1
# 3  Ward 1
# 4  Ward 1

# %%
Merged_Start_End_DF.to_csv("61Merged_Start_End_DF.csv")

# %% [markdown]
# ## 2.0 Associate csv File on Seasons

# %%
XF = pd.read_csv("00_Stacked_Dataframe.csv")

# %%
Station_shp = pd.read_csv("./XX_Processed_Data/A0_WashingtonDC_StationIDs_01.csv")

# %%
# Convert the column to datetime
XF['started_at'] = pd.to_datetime(XF['started_at'], format='%Y-%m-%d %H:%M:%S')
XF['ended_at'] = pd.to_datetime(XF['ended_at'], format='%Y-%m-%d %H:%M:%S')

XF["Station_ID"] = XF["start_station_id"]

# %%
# Merge the DataFrames based on the common fields 'ID'
merged_df = pd.merge(XF, Station_shp, on='Station_ID')

# %%
merged_df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat_x', 'start_lng_x', 'end_lat', 'end_lng',
#        'member_casual', 'Hour_(Starting)', 'Year', 'StationID_YearHour',
#        'Station_ID', 'start_station', 'start_lat_y', 'start_lng_y',
#        'Neighb_Cls', 'Ward', 'Day_Type'],
#       dtype='object')

# %%
# Define a function to label each date as weekday or weekend
def categorize_weekday_or_weekend(date):
    if date.weekday() < 5:  # 0-4 represent Monday to Friday (weekdays)
        return 'Weekday'
    else:
        return 'Weekend'

# Apply the function to create a new column 'Day_Type'
merged_df['Day_Type'] = merged_df['started_at'].apply(categorize_weekday_or_weekend)

# %%
merged_df['end_station_id'] = (merged_df['end_station_id'].astype(int)).astype(str)
merged_df['End_StationID_YearHour_Season'] = merged_df['end_station_id'] + "_" + merged_df['Year'].astype(str) + "_" + merged_df['Hour_(Starting)'].astype(str) + "_" + merged_df["Season"].astype(str) + "_" + merged_df["Day_Type"] 
merged_df["Start_StationID_YearHour_Season"] = merged_df["StationID_YearHour"] + "_" + merged_df["Season"].astype(str) + "_" + merged_df["Day_Type"]

# %%
merged_df.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  FF02EE3AE115F951  classic_bike 2021-07-04 21:57:56 2021-07-04 22:00:43
# 1  EAD3303AA5518C14  classic_bike 2021-07-24 16:26:54 2021-07-24 16:44:57
# 2  4CAAF169950650A7  classic_bike 2021-07-17 21:00:02 2021-07-17 21:21:27
# 3  2474026AF600F1FF  classic_bike 2021-07-09 19:10:59 2021-07-09 19:28:11
# 4  E5C209B34B279DB7  classic_bike 2021-07-25 19:05:05 2021-07-25 19:24:10
#
#   start_station_name  start_station_id end_station_name end_station_id  \
# 0      8th & K St NE             31660    6th & K St NE          31645
# 1      8th & K St NE             31660   10th & U St NW          31111
# 2      8th & K St NE             31660   10th & U St NW          31111
# 3      8th & K St NE             31660    1st & D St SE          31643
# 4      8th & K St NE             31660    1st & K St SE          31628
#
#    start_lat_x  start_lng_x  ...  Season  Station_ID Day_Type  start_station  \
# 0    38.902732    -76.99515  ...  Summer       31660  Weekend  8th & K St NE
# 1    38.902732    -76.99515  ...  Summer       31660  Weekend  8th & K St NE
# 2    38.902732    -76.99515  ...  Summer       31660  Weekend  8th & K St NE
# 3    38.902732    -76.99515  ...  Summer       31660  Weekday  8th & K St NE
# 4    38.902732    -76.99515  ...  Summer       31660  Weekend  8th & K St NE
#
#    start_lat_y start_lng_y  Neighb_Cls    Ward End_StationID_YearHour_Season  \
# 0    38.902657  -76.995111  Cluster 25  Ward 6  31645_2021_21_Summer_Weekend
# 1    38.902657  -76.995111  Cluster 25  Ward 6  31111_2021_16_Summer_Weekend
# 2    38.902657  -76.995111  Cluster 25  Ward 6  31111_2021_21_Summer_Weekend
# 3    38.902657  -76.995111  Cluster 25  Ward 6  31643_2021_19_Summer_Weekday
# 4    38.902657  -76.995111  Cluster 25  Ward 6  31628_2021_19_Summer_Weekend
#
#   Start_StationID_YearHour_Season
# 0    31660_2021_21_Summer_Weekend
# 1    31660_2021_16_Summer_Weekend
# 2    31660_2021_21_Summer_Weekend
# 3    31660_2021_19_Summer_Weekday
# 4    31660_2021_19_Summer_Weekend
#
# [5 rows x 26 columns]

# %%
Start_End_DF = pd.DataFrame()

# %%
Hours = list(range(0,24))

for i in Hours:
    filt1 = merged_df["started_at"].dt.hour == i

    x = merged_df[ filt1 ]
    Start_Stats = x["Start_StationID_YearHour_Season"].value_counts()
    End_Stats = x['End_StationID_YearHour_Season'].value_counts()

    Start_DF = pd.DataFrame(Start_Stats)
    End_DF = pd.DataFrame(End_Stats)
    
    End_DF = End_DF.reset_index()
    End_DF.rename(columns = {"End_StationID_YearHour_Season": "Arrival Count"}, inplace=True)
    
    Start_DF = Start_DF.reset_index()
    Start_DF.rename(columns = {"Start_StationID_YearHour_Season": "Deperture Count"}, inplace=True)
    
    # Merge the DataFrames based on the common fields 'ID'
    Start_End_XX = pd.merge(Start_DF, End_DF, on='index')

    # Concatenate df2 under df1
    Start_End_DF = pd.concat([Start_End_DF, Start_End_XX], ignore_index=True)

# %%
Start_End_DF
# Out:
#                                index  Deperture Count  Arrival Count
# 0        31114_2022_0_Summer_Weekend              208             80
# 1        31114_2023_0_Spring_Weekend              186             61
# 2        31202_2022_0_Summer_Weekend              168             79
# 3          31114_2022_0_Fall_Weekend              152             61
# 4          31114_2021_0_Fall_Weekend              144             76
# ...                              ...              ...            ...
# 128546  31665_2021_23_Summer_Weekday                1              8
# 128547  31530_2023_23_Winter_Weekend                1              4
# 128548    31530_2022_23_Fall_Weekend                1              2
# 128549  31530_2022_23_Spring_Weekend                1              5
# 128550    31307_2022_23_Fall_Weekend                1              6
#
# [128551 rows x 3 columns]

# %%
Start_End_DF[['StationID', 'Year', 'Hour', 'Season', 'Day_Type']] = Start_End_DF['index'].str.split('_', expand=True)
Start_End_DF.drop(columns = ["index"], inplace=True )

# %%
Start_End_DF
# Out:
#         Deperture Count  Arrival Count StationID  Year Hour  Season Day_Type
# 0                   208             80     31114  2022    0  Summer  Weekend
# 1                   186             61     31114  2023    0  Spring  Weekend
# 2                   168             79     31202  2022    0  Summer  Weekend
# 3                   152             61     31114  2022    0    Fall  Weekend
# 4                   144             76     31114  2021    0    Fall  Weekend
# ...                 ...            ...       ...   ...  ...     ...      ...
# 128546                1              8     31665  2021   23  Summer  Weekday
# 128547                1              4     31530  2023   23  Winter  Weekend
# 128548                1              2     31530  2022   23    Fall  Weekend
# 128549                1              5     31530  2022   23  Spring  Weekend
# 128550                1              6     31307  2022   23    Fall  Weekend
#
# [128551 rows x 7 columns]

# %%
# Start_End_DF.to_csv("64For_Seasonal_Hourly_DayType_Dynamics_Year.csv")

# %% [markdown]
# ## Taking Year wise Average Values

# %%
Stations = list(Start_End_DF["StationID"].unique())
Seasons = list(Start_End_DF["Season"].unique())
Hours = list(Start_End_DF["Hour"].unique())
Day_Type = list(Start_End_DF["Day_Type"].unique())

# %%
Day_Type[1]
# Out:
# 'Weekday'

# %%
X = Start_End_DF.groupby(['StationID']).get_group("31114")

# %%
X = Start_End_DF.groupby(['StationID']).get_group("31114")
filt1 = X["Season"] == Seasons[0]
filt2 = X["Hour"] == Hours[17]
# filt3 = X["Day_Type"] == Day_Type[0]
# df = X.loc[filt1 & filt2 & filt3]
df = X.loc[filt1 & filt2]

DCount = df["Deperture Count"].agg("mean")
ACount = df["Arrival Count"].agg("mean")
df
# Out:
#        Deperture Count  Arrival Count StationID  Year Hour  Season Day_Type
# 87273              272            384     31114  2022   17  Summer  Weekday
# 87559              210            265     31114  2023   17  Summer  Weekday
# 88056              148            152     31114  2021   17  Summer  Weekday
# 88529              107            115     31114  2022   17  Summer  Weekend
# 89483               60             77     31114  2023   17  Summer  Weekend
# 89857               49             62     31114  2021   17  Summer  Weekend

# %%
Seasonal_Hour_DF = pd.DataFrame()

# %%
# for i in Stations:
#     X = Start_End_DF.groupby(['StationID']).get_group(i)
    
#     for j in Seasons:
#         filt1 = X["Season"] == j
        
#         for m in Day_Type:
#             filt3 = X["Day_Type"] == m
        
#         for k in Hours:
#             filt2 = X["Hour"] == k
#             df = X.loc[filt1 & filt2 & filt3]
            
#             df.size
#             if df.size == 0:
#                 print(f"{k} hours of {i} station in {m} on {j} does not have any entry")
#                 break

#             DCount = df["Deperture Count"].agg("mean")
#             ACount = df["Arrival Count"].agg("mean")

#             #Hour
#             Hour = k
#             #Station_ID
#             StationID = i
#             #Season
#             Season = j
#             #DayType
#             DayType = m
            
#             # Create a new row as a dictionary
#             new_row = {"Hour_(Starting)" : Hour,
#                        'StationID' : StationID,
#                        "Season" : Season,
#                        "Day_Type" : DayType,
#                        "Deperture Count" : DCount, 
#                        "Arrival Count" : ACount}

#             x = (pd.DataFrame([new_row]))
#             Seasonal_Hour_DF = pd.concat([Seasonal_Hour_DF,x], axis=0)

# %%
for i in Stations:
    X = Start_End_DF.groupby(['StationID']).get_group(i)
    
    for j in Seasons:
        filt1 = X["Season"] == j
        filt3 = X["Day_Type"] == Day_Type[0]
        
        for k in Hours:
            filt2 = X["Hour"] == k
            df = X.loc[filt1 & filt2 & filt3]
            
            df.size
            if df.size == 0:
                print(f"{k} hours of {i} station in {Day_Type[0]} on {j} does not have any entry")
                break

            DCount = df["Deperture Count"].agg("mean")
            ACount = df["Arrival Count"].agg("mean")

            #Hour
            Hour = k
            #Station_ID
            StationID = i
            #Season
            Season = j
            #DayType
            DayType = Day_Type[0]
            
            # Create a new row as a dictionary
            new_row = {"Hour_(Starting)" : Hour,
                       'StationID' : StationID,
                       "Season" : Season,
                       "Day_Type" : DayType,
                       "Deperture Count" : DCount, 
                       "Arrival Count" : ACount}

            x = (pd.DataFrame([new_row]))
            Seasonal_Hour_DF = pd.concat([Seasonal_Hour_DF,x], axis=0)
# Out:
# 4 hours of 31114 station in Weekday on Winter does not have any entry
# 5 hours of 31202 station in Weekday on Spring does not have any entry
# 5 hours of 31327 station in Weekday on Fall does not have any entry
# 5 hours of 31327 station in Weekday on Winter does not have any entry
# 5 hours of 31109 station in Weekday on Spring does not have any entry
# 5 hours of 31109 station in Weekday on Winter does not have any entry
# 5 hours of 31102 station in Weekday on Summer does not have any entry
# 4 hours of 31102 station in Weekday on Winter does not have any entry
# 4 hours of 31104 station in Weekday on Spring does not have any entry
# 5 hours of 31104 station in Weekday on Fall does not have any entry
# 4 hours of 31104 station in Weekday on Winter does not have any entry
# 4 hours of 31266 station in Weekday on Winter does not have any entry
# 4 hours of 31289 station in Weekday on Fall does not have any entry
# 3 hours of 31289 station in Weekday on Winter does not have any entry
# 5 hours of 31201 station in Weekday on Spring does not have any entry
# 4 hours of 31201 station in Weekday on Winter does not have any entry
# 5 hours of 31232 station in Weekday on Spring does not have any entry
# 6 hours of 31221 station in Weekday on Summer does not have any entry
# 6 hours of 31221 station in Weekday on Fall does not have any entry
# 4 hours of 31221 station in Weekday on Winter does not have any entry
# 5 hours of 31134 station in Weekday on Summer does not have any entry
# 5 hours of 31134 station in Weekday on Spring does not have any entry
# 5 hours of 31111 station in Weekday on Spring does not have any entry
# 5 hours of 31111 station in Weekday on Fall does not have any entry
# 5 hours of 31111 station in Weekday on Winter does not have any entry
# 3 hours of 31258 station in Weekday on Spring does not have any entry
# 4 hours of 31258 station in Weekday on Fall does not have any entry
# 3 hours of 31258 station in Weekday on Winter does not have any entry
# 5 hours of 31627 station in Weekday on Spring does not have any entry
# 6 hours of 31627 station in Weekday on Winter does not have any entry
# 5 hours of 31623 station in Weekday on Spring does not have any entry
# 5 hours of 31116 station in Weekday on Winter does not have any entry
# 5 hours of 31603 station in Weekday on Winter does not have any entry
# 4 hours of 31609 station in Weekday on Fall does not have any entry
# 4 hours of 31609 station in Weekday on Winter does not have any entry
# 5 hours of 31245 station in Weekday on Winter does not have any entry
# 5 hours of 31223 station in Weekday on Winter does not have any entry
# 5 hours of 31200 station in Weekday on Winter does not have any entry
# 4 hours of 31628 station in Weekday on Spring does not have any entry
# 4 hours of 31628 station in Weekday on Winter does not have any entry
# 4 hours of 31642 station in Weekday on Spring does not have any entry
# 5 hours of 31642 station in Weekday on Winter does not have any entry
# 5 hours of 31506 station in Weekday on Spring does not have any entry
# 5 hours of 31506 station in Weekday on Winter does not have any entry
# 5 hours of 31280 station in Weekday on Spring does not have any entry
# 4 hours of 31280 station in Weekday on Fall does not have any entry
# 5 hours of 31280 station in Weekday on Winter does not have any entry
# 5 hours of 31401 station in Weekday on Winter does not have any entry
# 4 hours of 31125 station in Weekday on Winter does not have any entry
# 5 hours of 31330 station in Weekday on Fall does not have any entry
# 5 hours of 31330 station in Weekday on Winter does not have any entry
# 5 hours of 31209 station in Weekday on Spring does not have any entry
# 4 hours of 31209 station in Weekday on Winter does not have any entry
# 4 hours of 31265 station in Weekday on Winter does not have any entry
# 5 hours of 31215 station in Weekday on Spring does not have any entry
# 3 hours of 31215 station in Weekday on Fall does not have any entry
# 4 hours of 31215 station in Weekday on Winter does not have any entry
# 4 hours of 31613 station in Weekday on Spring does not have any entry
# 4 hours of 31613 station in Weekday on Fall does not have any entry
# 6 hours of 31613 station in Weekday on Winter does not have any entry
# 3 hours of 31655 station in Weekday on Summer does not have any entry
# 3 hours of 31655 station in Weekday on Winter does not have any entry
# 4 hours of 31247 station in Weekday on Summer does not have any entry
# 4 hours of 31247 station in Weekday on Spring does not have any entry
# 4 hours of 31247 station in Weekday on Fall does not have any entry
# 4 hours of 31247 station in Weekday on Winter does not have any entry
# 4 hours of 31321 station in Weekday on Spring does not have any entry
# 4 hours of 31321 station in Weekday on Fall does not have any entry
# 3 hours of 31321 station in Weekday on Winter does not have any entry
# 4 hours of 31119 station in Weekday on Spring does not have any entry
# 5 hours of 31119 station in Weekday on Winter does not have any entry
# 5 hours of 31239 station in Weekday on Winter does not have any entry
# 3 hours of 31246 station in Weekday on Winter does not have any entry
# 3 hours of 31275 station in Weekday on Winter does not have any entry
# 4 hours of 31248 station in Weekday on Summer does not have any entry
# 3 hours of 31248 station in Weekday on Spring does not have any entry
# 4 hours of 31248 station in Weekday on Fall does not have any entry
# 1 hours of 31248 station in Weekday on Winter does not have any entry
# 5 hours of 31296 station in Weekday on Spring does not have any entry
# 4 hours of 31296 station in Weekday on Winter does not have any entry
# 5 hours of 31620 station in Weekday on Spring does not have any entry
# 6 hours of 31620 station in Weekday on Winter does not have any entry
# 5 hours of 31286 station in Weekday on Fall does not have any entry
# 4 hours of 31212 station in Weekday on Winter does not have any entry
# 4 hours of 31130 station in Weekday on Winter does not have any entry
# 4 hours of 31531 station in Weekday on Summer does not have any entry
# 4 hours of 31531 station in Weekday on Spring does not have any entry
# 3 hours of 31531 station in Weekday on Fall does not have any entry
# 4 hours of 31531 station in Weekday on Winter does not have any entry
# 4 hours of 31324 station in Weekday on Winter does not have any entry
# 5 hours of 31107 station in Weekday on Fall does not have any entry
# 5 hours of 31208 station in Weekday on Summer does not have any entry
# 4 hours of 31208 station in Weekday on Spring does not have any entry
# 4 hours of 31208 station in Weekday on Fall does not have any entry
# 3 hours of 31208 station in Weekday on Winter does not have any entry
# 4 hours of 31108 station in Weekday on Spring does not have any entry
# 3 hours of 31108 station in Weekday on Winter does not have any entry
# 6 hours of 31117 station in Weekday on Winter does not have any entry
# 4 hours of 31264 station in Weekday on Summer does not have any entry
# 4 hours of 31264 station in Weekday on Spring does not have any entry
# 2 hours of 31264 station in Weekday on Winter does not have any entry
# 4 hours of 31611 station in Weekday on Spring does not have any entry
# 4 hours of 31611 station in Weekday on Fall does not have any entry
# 3 hours of 31611 station in Weekday on Winter does not have any entry
# 4 hours of 31646 station in Weekday on Summer does not have any entry
# 3 hours of 31646 station in Weekday on Spring does not have any entry
# 4 hours of 31646 station in Weekday on Winter does not have any entry
# 4 hours of 31624 station in Weekday on Spring does not have any entry
# 3 hours of 31624 station in Weekday on Winter does not have any entry
# 4 hours of 31311 station in Weekday on Summer does not have any entry
# 3 hours of 31311 station in Weekday on Spring does not have any entry
# 0 hours of 31311 station in Weekday on Fall does not have any entry
# 0 hours of 31311 station in Weekday on Winter does not have any entry
# 5 hours of 31509 station in Weekday on Winter does not have any entry
# 4 hours of 31604 station in Weekday on Spring does not have any entry
# 6 hours of 31604 station in Weekday on Winter does not have any entry
# 4 hours of 31332 station in Weekday on Summer does not have any entry
# 4 hours of 31332 station in Weekday on Fall does not have any entry
# 5 hours of 31332 station in Weekday on Winter does not have any entry
# 5 hours of 31614 station in Weekday on Summer does not have any entry
# 0 hours of 31614 station in Weekday on Spring does not have any entry
# 5 hours of 31614 station in Weekday on Fall does not have any entry
# 0 hours of 31614 station in Weekday on Winter does not have any entry
# 4 hours of 31328 station in Weekday on Winter does not have any entry
# 5 hours of 31672 station in Weekday on Summer does not have any entry
# 5 hours of 31672 station in Weekday on Spring does not have any entry
# 5 hours of 31672 station in Weekday on Fall does not have any entry
# 3 hours of 31672 station in Weekday on Winter does not have any entry
# 4 hours of 31256 station in Weekday on Summer does not have any entry
# 4 hours of 31256 station in Weekday on Spring does not have any entry
# 4 hours of 31256 station in Weekday on Fall does not have any entry
# 5 hours of 31256 station in Weekday on Winter does not have any entry
# 4 hours of 31608 station in Weekday on Spring does not have any entry
# 3 hours of 31608 station in Weekday on Fall does not have any entry
# 4 hours of 31608 station in Weekday on Winter does not have any entry
# 4 hours of 31503 station in Weekday on Winter does not have any entry
# 4 hours of 31230 station in Weekday on Spring does not have any entry
# 4 hours of 31230 station in Weekday on Winter does not have any entry
# 4 hours of 31113 station in Weekday on Winter does not have any entry
# 4 hours of 31135 station in Weekday on Winter does not have any entry
# 4 hours of 31278 station in Weekday on Winter does not have any entry
# 4 hours of 31122 station in Weekday on Winter does not have any entry
# 4 hours of 31634 station in Weekday on Spring does not have any entry
# 5 hours of 31634 station in Weekday on Fall does not have any entry
# 3 hours of 31634 station in Weekday on Winter does not have any entry
# 4 hours of 31650 station in Weekday on Spring does not have any entry
# 5 hours of 31650 station in Weekday on Fall does not have any entry
# 3 hours of 31650 station in Weekday on Winter does not have any entry
# 4 hours of 31616 station in Weekday on Spring does not have any entry
# 5 hours of 31616 station in Weekday on Winter does not have any entry
# 5 hours of 31295 station in Weekday on Fall does not have any entry
# 3 hours of 31295 station in Weekday on Winter does not have any entry
# 5 hours of 31666 station in Weekday on Spring does not have any entry
# 5 hours of 31666 station in Weekday on Winter does not have any entry
# 4 hours of 31225 station in Weekday on Summer does not have any entry
# 5 hours of 31225 station in Weekday on Fall does not have any entry
# 4 hours of 31225 station in Weekday on Winter does not have any entry
# 5 hours of 31236 station in Weekday on Summer does not have any entry
# 4 hours of 31236 station in Weekday on Winter does not have any entry
# 3 hours of 31293 station in Weekday on Summer does not have any entry
# 3 hours of 31293 station in Weekday on Spring does not have any entry
# 2 hours of 31293 station in Weekday on Fall does not have any entry
# 0 hours of 31293 station in Weekday on Winter does not have any entry
# 4 hours of 31110 station in Weekday on Winter does not have any entry
# 3 hours of 31669 station in Weekday on Summer does not have any entry
# 2 hours of 31669 station in Weekday on Spring does not have any entry
# 3 hours of 31669 station in Weekday on Fall does not have any entry
# 3 hours of 31669 station in Weekday on Winter does not have any entry
# 5 hours of 31250 station in Weekday on Winter does not have any entry
# 5 hours of 31268 station in Weekday on Summer does not have any entry
# 5 hours of 31268 station in Weekday on Fall does not have any entry
# 4 hours of 31268 station in Weekday on Winter does not have any entry
# 4 hours of 31652 station in Weekday on Summer does not have any entry
# 4 hours of 31652 station in Weekday on Spring does not have any entry
# 3 hours of 31652 station in Weekday on Fall does not have any entry
# 4 hours of 31652 station in Weekday on Winter does not have any entry
# 4 hours of 31285 station in Weekday on Spring does not have any entry
# 6 hours of 31285 station in Weekday on Winter does not have any entry
# 4 hours of 31263 station in Weekday on Fall does not have any entry
# 3 hours of 31219 station in Weekday on Summer does not have any entry
# 1 hours of 31219 station in Weekday on Spring does not have any entry
# 1 hours of 31219 station in Weekday on Fall does not have any entry
# 0 hours of 31219 station in Weekday on Winter does not have any entry
# 5 hours of 31283 station in Weekday on Spring does not have any entry
# 5 hours of 31283 station in Weekday on Fall does not have any entry
# 3 hours of 31283 station in Weekday on Winter does not have any entry
# 5 hours of 31602 station in Weekday on Spring does not have any entry
# 4 hours of 31602 station in Weekday on Winter does not have any entry
# 5 hours of 31651 station in Weekday on Winter does not have any entry
# 6 hours of 31205 station in Weekday on Winter does not have any entry
# 5 hours of 31120 station in Weekday on Winter does not have any entry
# 4 hours of 31129 station in Weekday on Fall does not have any entry
# 3 hours of 31129 station in Weekday on Winter does not have any entry
# 4 hours of 31238 station in Weekday on Spring does not have any entry
# 4 hours of 31238 station in Weekday on Fall does not have any entry
# 4 hours of 31238 station in Weekday on Winter does not have any entry
# 4 hours of 31123 station in Weekday on Spring does not have any entry
# 5 hours of 31123 station in Weekday on Fall does not have any entry
# 4 hours of 31123 station in Weekday on Winter does not have any entry
# 5 hours of 31274 station in Weekday on Summer does not have any entry
# 4 hours of 31274 station in Weekday on Spring does not have any entry
# 4 hours of 31274 station in Weekday on Fall does not have any entry
# 0 hours of 31274 station in Weekday on Winter does not have any entry
# 4 hours of 31127 station in Weekday on Spring does not have any entry
# 2 hours of 31127 station in Weekday on Winter does not have any entry
# 1 hours of 31290 station in Weekday on Spring does not have any entry
# 4 hours of 31290 station in Weekday on Fall does not have any entry
# 0 hours of 31290 station in Weekday on Winter does not have any entry
# 4 hours of 31222 station in Weekday on Spring does not have any entry
# 5 hours of 31222 station in Weekday on Fall does not have any entry
# 1 hours of 31222 station in Weekday on Winter does not have any entry
# 3 hours of 31237 station in Weekday on Winter does not have any entry
# 4 hours of 31227 station in Weekday on Winter does not have any entry
# 4 hours of 31204 station in Weekday on Summer does not have any entry
# 3 hours of 31204 station in Weekday on Spring does not have any entry
# 2 hours of 31204 station in Weekday on Winter does not have any entry
# 4 hours of 31257 station in Weekday on Winter does not have any entry
# 4 hours of 31299 station in Weekday on Spring does not have any entry
# 4 hours of 31299 station in Weekday on Fall does not have any entry
# 4 hours of 31299 station in Weekday on Winter does not have any entry
# 5 hours of 31515 station in Weekday on Summer does not have any entry
# 2 hours of 31515 station in Weekday on Spring does not have any entry
# 2 hours of 31515 station in Weekday on Fall does not have any entry
# 1 hours of 31515 station in Weekday on Winter does not have any entry
# 6 hours of 31662 station in Weekday on Winter does not have any entry
# 3 hours of 31621 station in Weekday on Summer does not have any entry
# 1 hours of 31621 station in Weekday on Spring does not have any entry
# 1 hours of 31621 station in Weekday on Fall does not have any entry
# 2 hours of 31621 station in Weekday on Winter does not have any entry
# 4 hours of 31224 station in Weekday on Spring does not have any entry
# 6 hours of 31224 station in Weekday on Fall does not have any entry
# 7 hours of 31224 station in Weekday on Winter does not have any entry
# 3 hours of 31277 station in Weekday on Summer does not have any entry
# 3 hours of 31277 station in Weekday on Spring does not have any entry
# 3 hours of 31277 station in Weekday on Fall does not have any entry
# 2 hours of 31277 station in Weekday on Winter does not have any entry
# 3 hours of 31641 station in Weekday on Summer does not have any entry
# 3 hours of 31641 station in Weekday on Spring does not have any entry
# 3 hours of 31641 station in Weekday on Fall does not have any entry
# 4 hours of 31641 station in Weekday on Winter does not have any entry
# 4 hours of 31638 station in Weekday on Spring does not have any entry
# 3 hours of 31638 station in Weekday on Fall does not have any entry
# 2 hours of 31249 station in Weekday on Spring does not have any entry
# 3 hours of 31249 station in Weekday on Fall does not have any entry
# 1 hours of 31249 station in Weekday on Winter does not have any entry
# 3 hours of 31115 station in Weekday on Winter does not have any entry
# 5 hours of 31131 station in Weekday on Spring does not have any entry
# 4 hours of 31131 station in Weekday on Winter does not have any entry
# 4 hours of 31294 station in Weekday on Summer does not have any entry
# 3 hours of 31294 station in Weekday on Spring does not have any entry
# 5 hours of 31294 station in Weekday on Fall does not have any entry
# 3 hours of 31294 station in Weekday on Winter does not have any entry
# 4 hours of 31133 station in Weekday on Summer does not have any entry
# 4 hours of 31133 station in Weekday on Fall does not have any entry
# 4 hours of 31133 station in Weekday on Winter does not have any entry
# 6 hours of 31419 station in Weekday on Spring does not have any entry
# 6 hours of 31419 station in Weekday on Fall does not have any entry
# 4 hours of 31270 station in Weekday on Summer does not have any entry
# 3 hours of 31270 station in Weekday on Spring does not have any entry
# 3 hours of 31270 station in Weekday on Fall does not have any entry
# 1 hours of 31270 station in Weekday on Winter does not have any entry
# 5 hours of 31291 station in Weekday on Summer does not have any entry
# 3 hours of 31291 station in Weekday on Winter does not have any entry
# 4 hours of 31235 station in Weekday on Summer does not have any entry
# 3 hours of 31235 station in Weekday on Spring does not have any entry
# 3 hours of 31235 station in Weekday on Fall does not have any entry
# 1 hours of 31235 station in Weekday on Winter does not have any entry
# 3 hours of 30201 station in Weekday on Summer does not have any entry
# 3 hours of 30201 station in Weekday on Spring does not have any entry
# 0 hours of 30201 station in Weekday on Fall does not have any entry
# 0 hours of 30201 station in Weekday on Winter does not have any entry
# 5 hours of 31312 station in Weekday on Winter does not have any entry
# 4 hours of 31323 station in Weekday on Spring does not have any entry
# 4 hours of 31323 station in Weekday on Fall does not have any entry
# 3 hours of 31323 station in Weekday on Winter does not have any entry
# 4 hours of 31505 station in Weekday on Fall does not have any entry
# 4 hours of 31505 station in Weekday on Winter does not have any entry
# 3 hours of 31674 station in Weekday on Summer does not have any entry
# 3 hours of 31674 station in Weekday on Spring does not have any entry
# 5 hours of 31674 station in Weekday on Fall does not have any entry
# 2 hours of 31674 station in Weekday on Winter does not have any entry
# 5 hours of 31276 station in Weekday on Summer does not have any entry
# 4 hours of 31276 station in Weekday on Spring does not have any entry
# 5 hours of 31639 station in Weekday on Spring does not have any entry
# 4 hours of 31639 station in Weekday on Fall does not have any entry
# 5 hours of 31639 station in Weekday on Winter does not have any entry
# 4 hours of 31610 station in Weekday on Summer does not have any entry
# 3 hours of 31610 station in Weekday on Spring does not have any entry
# 3 hours of 31610 station in Weekday on Fall does not have any entry
# 3 hours of 31610 station in Weekday on Winter does not have any entry
# 5 hours of 31527 station in Weekday on Fall does not have any entry
# 3 hours of 31527 station in Weekday on Winter does not have any entry
# 5 hours of 31118 station in Weekday on Winter does not have any entry
# 5 hours of 31615 station in Weekday on Summer does not have any entry
# 4 hours of 31615 station in Weekday on Spring does not have any entry
# 4 hours of 31615 station in Weekday on Winter does not have any entry
# 4 hours of 31654 station in Weekday on Summer does not have any entry
# 3 hours of 31654 station in Weekday on Spring does not have any entry
# 3 hours of 31654 station in Weekday on Fall does not have any entry
# 3 hours of 31654 station in Weekday on Winter does not have any entry
# 4 hours of 31298 station in Weekday on Fall does not have any entry
# 3 hours of 31298 station in Weekday on Winter does not have any entry
# 4 hours of 31303 station in Weekday on Summer does not have any entry
# 3 hours of 31303 station in Weekday on Spring does not have any entry
# 3 hours of 31303 station in Weekday on Fall does not have any entry
# 2 hours of 31303 station in Weekday on Winter does not have any entry
# 3 hours of 31254 station in Weekday on Spring does not have any entry
# 5 hours of 31254 station in Weekday on Fall does not have any entry
# 4 hours of 31254 station in Weekday on Winter does not have any entry
# 4 hours of 31618 station in Weekday on Summer does not have any entry
# 4 hours of 31618 station in Weekday on Spring does not have any entry
# 4 hours of 31618 station in Weekday on Fall does not have any entry
# 4 hours of 31618 station in Weekday on Winter does not have any entry
# 3 hours of 31233 station in Weekday on Summer does not have any entry
# 4 hours of 31233 station in Weekday on Fall does not have any entry
# 4 hours of 31233 station in Weekday on Winter does not have any entry
# 5 hours of 31216 station in Weekday on Spring does not have any entry
# 4 hours of 31216 station in Weekday on Fall does not have any entry
# 0 hours of 31216 station in Weekday on Winter does not have any entry
# 3 hours of 31533 station in Weekday on Summer does not have any entry
# 4 hours of 31533 station in Weekday on Spring does not have any entry
# 4 hours of 31533 station in Weekday on Fall does not have any entry
# 3 hours of 31533 station in Weekday on Winter does not have any entry
# 3 hours of 31271 station in Weekday on Spring does not have any entry
# 4 hours of 31271 station in Weekday on Fall does not have any entry
# 3 hours of 31271 station in Weekday on Winter does not have any entry
# 4 hours of 31306 station in Weekday on Summer does not have any entry
# 5 hours of 31306 station in Weekday on Spring does not have any entry
# 3 hours of 31306 station in Weekday on Fall does not have any entry
# 2 hours of 31306 station in Weekday on Winter does not have any entry
# 4 hours of 31243 station in Weekday on Summer does not have any entry
# 4 hours of 31243 station in Weekday on Spring does not have any entry
# 4 hours of 31243 station in Weekday on Winter does not have any entry
# 5 hours of 31121 station in Weekday on Spring does not have any entry
# 5 hours of 31121 station in Weekday on Fall does not have any entry
# 3 hours of 31121 station in Weekday on Winter does not have any entry
# 4 hours of 31661 station in Weekday on Spring does not have any entry
# 4 hours of 31661 station in Weekday on Winter does not have any entry
# 4 hours of 31636 station in Weekday on Winter does not have any entry
# 4 hours of 31105 station in Weekday on Spring does not have any entry
# 4 hours of 31105 station in Weekday on Fall does not have any entry
# 4 hours of 31105 station in Weekday on Winter does not have any entry
# 3 hours of 31635 station in Weekday on Summer does not have any entry
# 1 hours of 31635 station in Weekday on Spring does not have any entry
# 1 hours of 31635 station in Weekday on Fall does not have any entry
# 0 hours of 31635 station in Weekday on Winter does not have any entry
# 4 hours of 31240 station in Weekday on Summer does not have any entry
# 4 hours of 31240 station in Weekday on Spring does not have any entry
# 5 hours of 31240 station in Weekday on Fall does not have any entry
# 0 hours of 31240 station in Weekday on Winter does not have any entry
# 4 hours of 31262 station in Weekday on Summer does not have any entry
# 2 hours of 31262 station in Weekday on Spring does not have any entry
# 4 hours of 31262 station in Weekday on Fall does not have any entry
# 0 hours of 31262 station in Weekday on Winter does not have any entry
# 4 hours of 31668 station in Weekday on Spring does not have any entry
# 1 hours of 31668 station in Weekday on Winter does not have any entry
# 5 hours of 31325 station in Weekday on Fall does not have any entry
# 4 hours of 31325 station in Weekday on Winter does not have any entry
# 4 hours of 31226 station in Weekday on Summer does not have any entry
# 3 hours of 31226 station in Weekday on Spring does not have any entry
# 4 hours of 31226 station in Weekday on Fall does not have any entry
# 4 hours of 31226 station in Weekday on Winter does not have any entry
# 5 hours of 31292 station in Weekday on Summer does not have any entry
# 5 hours of 31292 station in Weekday on Spring does not have any entry
# 3 hours of 31292 station in Weekday on Fall does not have any entry
# 0 hours of 31292 station in Weekday on Winter does not have any entry
# 4 hours of 31288 station in Weekday on Spring does not have any entry
# 3 hours of 31288 station in Weekday on Fall does not have any entry
# 2 hours of 31288 station in Weekday on Winter does not have any entry
# 3 hours of 31625 station in Weekday on Summer does not have any entry
# 2 hours of 31625 station in Weekday on Spring does not have any entry
# 2 hours of 31625 station in Weekday on Fall does not have any entry
# 3 hours of 31625 station in Weekday on Winter does not have any entry
# 4 hours of 31517 station in Weekday on Summer does not have any entry
# 3 hours of 31517 station in Weekday on Spring does not have any entry
# 4 hours of 31517 station in Weekday on Fall does not have any entry
# 2 hours of 31517 station in Weekday on Winter does not have any entry
# 4 hours of 31287 station in Weekday on Summer does not have any entry
# 2 hours of 31287 station in Weekday on Spring does not have any entry
# 1 hours of 31287 station in Weekday on Fall does not have any entry
# 1 hours of 31287 station in Weekday on Winter does not have any entry
# 4 hours of 31657 station in Weekday on Spring does not have any entry
# 5 hours of 31657 station in Weekday on Fall does not have any entry
# 2 hours of 31657 station in Weekday on Winter does not have any entry
# 4 hours of 31252 station in Weekday on Summer does not have any entry
# 3 hours of 31252 station in Weekday on Spring does not have any entry
# 3 hours of 31252 station in Weekday on Winter does not have any entry
# 5 hours of 31210 station in Weekday on Summer does not have any entry
# 4 hours of 31210 station in Weekday on Spring does not have any entry
# 0 hours of 31210 station in Weekday on Fall does not have any entry
# 0 hours of 31210 station in Weekday on Winter does not have any entry
# 4 hours of 31255 station in Weekday on Fall does not have any entry
# 3 hours of 31255 station in Weekday on Winter does not have any entry
# 3 hours of 31302 station in Weekday on Summer does not have any entry
# 2 hours of 31302 station in Weekday on Spring does not have any entry
# 4 hours of 31302 station in Weekday on Fall does not have any entry
# 1 hours of 31302 station in Weekday on Winter does not have any entry
# 4 hours of 31519 station in Weekday on Summer does not have any entry
# 5 hours of 31519 station in Weekday on Spring does not have any entry
# 4 hours of 31519 station in Weekday on Fall does not have any entry
# 5 hours of 31519 station in Weekday on Winter does not have any entry
# 3 hours of 31536 station in Weekday on Fall does not have any entry
# 0 hours of 31536 station in Weekday on Winter does not have any entry
# 4 hours of 31297 station in Weekday on Spring does not have any entry
# 5 hours of 31297 station in Weekday on Fall does not have any entry
# 3 hours of 31297 station in Weekday on Winter does not have any entry
# 4 hours of 31631 station in Weekday on Spring does not have any entry
# 4 hours of 31631 station in Weekday on Fall does not have any entry
# 3 hours of 31631 station in Weekday on Winter does not have any entry
# 5 hours of 31619 station in Weekday on Spring does not have any entry
# 5 hours of 31619 station in Weekday on Fall does not have any entry
# 4 hours of 31619 station in Weekday on Winter does not have any entry
# 1 hours of 31100 station in Weekday on Summer does not have any entry
# 1 hours of 31100 station in Weekday on Spring does not have any entry
# 1 hours of 31100 station in Weekday on Fall does not have any entry
# 3 hours of 31100 station in Weekday on Winter does not have any entry
# 3 hours of 31272 station in Weekday on Summer does not have any entry
# 3 hours of 31272 station in Weekday on Spring does not have any entry
# 3 hours of 31272 station in Weekday on Fall does not have any entry
# 0 hours of 31272 station in Weekday on Winter does not have any entry
# 4 hours of 31828 station in Weekday on Summer does not have any entry
# 3 hours of 31828 station in Weekday on Spring does not have any entry
# 2 hours of 31828 station in Weekday on Fall does not have any entry
# 2 hours of 31828 station in Weekday on Winter does not have any entry
# 4 hours of 31244 station in Weekday on Spring does not have any entry
# 1 hours of 31244 station in Weekday on Fall does not have any entry
# 3 hours of 31244 station in Weekday on Winter does not have any entry
# 5 hours of 31516 station in Weekday on Summer does not have any entry
# 1 hours of 31516 station in Weekday on Spring does not have any entry
# 2 hours of 31516 station in Weekday on Fall does not have any entry
# 1 hours of 31516 station in Weekday on Winter does not have any entry
# 4 hours of 31103 station in Weekday on Summer does not have any entry
# 0 hours of 31103 station in Weekday on Spring does not have any entry
# 4 hours of 31103 station in Weekday on Fall does not have any entry
# 0 hours of 31103 station in Weekday on Winter does not have any entry
# 4 hours of 31617 station in Weekday on Summer does not have any entry
# 5 hours of 31617 station in Weekday on Spring does not have any entry
# 4 hours of 31617 station in Weekday on Fall does not have any entry
# 1 hours of 31617 station in Weekday on Winter does not have any entry
# 4 hours of 31269 station in Weekday on Summer does not have any entry
# 3 hours of 31269 station in Weekday on Spring does not have any entry
# 3 hours of 31269 station in Weekday on Fall does not have any entry
# 2 hours of 31269 station in Weekday on Winter does not have any entry
# 3 hours of 31136 station in Weekday on Summer does not have any entry
# 5 hours of 31136 station in Weekday on Spring does not have any entry
# 4 hours of 31136 station in Weekday on Fall does not have any entry
# 4 hours of 31136 station in Weekday on Winter does not have any entry
# 3 hours of 31667 station in Weekday on Summer does not have any entry
# 1 hours of 31667 station in Weekday on Spring does not have any entry
# 3 hours of 31667 station in Weekday on Fall does not have any entry
# 0 hours of 31667 station in Weekday on Winter does not have any entry
# 3 hours of 31260 station in Weekday on Spring does not have any entry
# 3 hours of 31260 station in Weekday on Fall does not have any entry
# 4 hours of 31260 station in Weekday on Winter does not have any entry
# 3 hours of 31314 station in Weekday on Summer does not have any entry
# 2 hours of 31314 station in Weekday on Spring does not have any entry
# 3 hours of 31314 station in Weekday on Fall does not have any entry
# 1 hours of 31314 station in Weekday on Winter does not have any entry
# 4 hours of 31304 station in Weekday on Summer does not have any entry
# 4 hours of 31304 station in Weekday on Spring does not have any entry
# 3 hours of 31304 station in Weekday on Fall does not have any entry
# 3 hours of 31304 station in Weekday on Winter does not have any entry
# 4 hours of 31606 station in Weekday on Spring does not have any entry
# 4 hours of 31606 station in Weekday on Winter does not have any entry
# 4 hours of 31637 station in Weekday on Summer does not have any entry
# 3 hours of 31637 station in Weekday on Spring does not have any entry
# 5 hours of 31637 station in Weekday on Fall does not have any entry
# 1 hours of 31637 station in Weekday on Winter does not have any entry
# 4 hours of 31643 station in Weekday on Summer does not have any entry
# 3 hours of 31643 station in Weekday on Spring does not have any entry
# 4 hours of 31643 station in Weekday on Fall does not have any entry
# 3 hours of 31643 station in Weekday on Winter does not have any entry
# 3 hours of 31408 station in Weekday on Summer does not have any entry
# 2 hours of 31408 station in Weekday on Spring does not have any entry
# 1 hours of 31408 station in Weekday on Fall does not have any entry
# 1 hours of 31408 station in Weekday on Winter does not have any entry
# 5 hours of 31231 station in Weekday on Summer does not have any entry
# 3 hours of 31231 station in Weekday on Spring does not have any entry
# 5 hours of 31231 station in Weekday on Fall does not have any entry
# 0 hours of 31231 station in Weekday on Winter does not have any entry
# 4 hours of 31640 station in Weekday on Spring does not have any entry
# 6 hours of 31640 station in Weekday on Fall does not have any entry
# 3 hours of 31640 station in Weekday on Winter does not have any entry
# 3 hours of 31675 station in Weekday on Summer does not have any entry
# 3 hours of 31675 station in Weekday on Spring does not have any entry
# 4 hours of 31675 station in Weekday on Fall does not have any entry
# 2 hours of 31675 station in Weekday on Winter does not have any entry
# 4 hours of 31279 station in Weekday on Summer does not have any entry
# 1 hours of 31279 station in Weekday on Spring does not have any entry
# 4 hours of 31279 station in Weekday on Fall does not have any entry
# 1 hours of 31279 station in Weekday on Winter does not have any entry
# 4 hours of 31518 station in Weekday on Winter does not have any entry
# 4 hours of 31284 station in Weekday on Summer does not have any entry
# 4 hours of 31284 station in Weekday on Spring does not have any entry
# 3 hours of 31284 station in Weekday on Fall does not have any entry
# 0 hours of 31284 station in Weekday on Winter does not have any entry
# 4 hours of 31242 station in Weekday on Summer does not have any entry
# 0 hours of 31242 station in Weekday on Spring does not have any entry
# 4 hours of 31242 station in Weekday on Fall does not have any entry
# 1 hours of 31242 station in Weekday on Winter does not have any entry
# 4 hours of 31605 station in Weekday on Summer does not have any entry
# 5 hours of 31605 station in Weekday on Spring does not have any entry
# 4 hours of 31605 station in Weekday on Fall does not have any entry
# 4 hours of 31605 station in Weekday on Winter does not have any entry
# 3 hours of 31217 station in Weekday on Summer does not have any entry
# 1 hours of 31217 station in Weekday on Spring does not have any entry
# 1 hours of 31217 station in Weekday on Fall does not have any entry
# 1 hours of 31217 station in Weekday on Winter does not have any entry
# 4 hours of 31500 station in Weekday on Summer does not have any entry
# 3 hours of 31500 station in Weekday on Spring does not have any entry
# 4 hours of 31500 station in Weekday on Fall does not have any entry
# 4 hours of 31500 station in Weekday on Winter does not have any entry
# 3 hours of 31664 station in Weekday on Summer does not have any entry
# 1 hours of 31664 station in Weekday on Spring does not have any entry
# 3 hours of 31664 station in Weekday on Fall does not have any entry
# 3 hours of 31664 station in Weekday on Winter does not have any entry
# 3 hours of 31310 station in Weekday on Spring does not have any entry
# 6 hours of 31310 station in Weekday on Fall does not have any entry
# 3 hours of 31310 station in Weekday on Winter does not have any entry
# 3 hours of 31645 station in Weekday on Summer does not have any entry
# 2 hours of 31645 station in Weekday on Spring does not have any entry
# 3 hours of 31645 station in Weekday on Fall does not have any entry
# 2 hours of 31645 station in Weekday on Winter does not have any entry
# 4 hours of 31253 station in Weekday on Summer does not have any entry
# 2 hours of 31253 station in Weekday on Spring does not have any entry
# 4 hours of 31253 station in Weekday on Fall does not have any entry
# 3 hours of 31253 station in Weekday on Winter does not have any entry
# 2 hours of 33200 station in Weekday on Summer does not have any entry
# 0 hours of 33200 station in Weekday on Spring does not have any entry
# 0 hours of 33200 station in Weekday on Fall does not have any entry
# 0 hours of 33200 station in Weekday on Winter does not have any entry
# 3 hours of 31504 station in Weekday on Spring does not have any entry
# 3 hours of 31504 station in Weekday on Fall does not have any entry
# 1 hours of 31504 station in Weekday on Winter does not have any entry
# 5 hours of 31522 station in Weekday on Spring does not have any entry
# 5 hours of 31522 station in Weekday on Fall does not have any entry
# 3 hours of 31522 station in Weekday on Winter does not have any entry
# 5 hours of 31648 station in Weekday on Summer does not have any entry
# 0 hours of 31648 station in Weekday on Spring does not have any entry
# 2 hours of 31648 station in Weekday on Fall does not have any entry
# 1 hours of 31648 station in Weekday on Winter does not have any entry
# 5 hours of 31421 station in Weekday on Summer does not have any entry
# 1 hours of 31421 station in Weekday on Spring does not have any entry
# 4 hours of 31421 station in Weekday on Fall does not have any entry
# 1 hours of 31421 station in Weekday on Winter does not have any entry
# 4 hours of 31211 station in Weekday on Summer does not have any entry
# 2 hours of 31211 station in Weekday on Spring does not have any entry
# 2 hours of 31211 station in Weekday on Fall does not have any entry
# 0 hours of 31211 station in Weekday on Winter does not have any entry
# 0 hours of 31301 station in Weekday on Summer does not have any entry
# 4 hours of 31301 station in Weekday on Spring does not have any entry
# 4 hours of 31301 station in Weekday on Fall does not have any entry
# 0 hours of 31301 station in Weekday on Winter does not have any entry
# 4 hours of 31629 station in Weekday on Summer does not have any entry
# 4 hours of 31629 station in Weekday on Spring does not have any entry
# 3 hours of 31629 station in Weekday on Fall does not have any entry
# 3 hours of 31629 station in Weekday on Winter does not have any entry
# 3 hours of 31659 station in Weekday on Summer does not have any entry
# 1 hours of 31659 station in Weekday on Spring does not have any entry
# 4 hours of 31659 station in Weekday on Fall does not have any entry
# 4 hours of 31659 station in Weekday on Winter does not have any entry
# 2 hours of 31633 station in Weekday on Summer does not have any entry
# 2 hours of 31633 station in Weekday on Spring does not have any entry
# 0 hours of 31633 station in Weekday on Fall does not have any entry
# 2 hours of 31633 station in Weekday on Winter does not have any entry
# 4 hours of 31261 station in Weekday on Summer does not have any entry
# 1 hours of 31261 station in Weekday on Spring does not have any entry
# 1 hours of 31261 station in Weekday on Fall does not have any entry
# 0 hours of 31261 station in Weekday on Winter does not have any entry
# 5 hours of 31106 station in Weekday on Spring does not have any entry
# 4 hours of 31106 station in Weekday on Fall does not have any entry
# 4 hours of 31106 station in Weekday on Winter does not have any entry
# 3 hours of 31138 station in Weekday on Summer does not have any entry
# 1 hours of 31138 station in Weekday on Spring does not have any entry
# 3 hours of 31138 station in Weekday on Fall does not have any entry
# 1 hours of 31138 station in Weekday on Winter does not have any entry
# 4 hours of 31540 station in Weekday on Summer does not have any entry
# 2 hours of 31540 station in Weekday on Spring does not have any entry
# 0 hours of 31540 station in Weekday on Fall does not have any entry
# 3 hours of 31540 station in Weekday on Winter does not have any entry
# 4 hours of 31670 station in Weekday on Summer does not have any entry
# 3 hours of 31670 station in Weekday on Spring does not have any entry
# 0 hours of 31670 station in Weekday on Fall does not have any entry
# 0 hours of 31670 station in Weekday on Winter does not have any entry
# 2 hours of 31673 station in Weekday on Summer does not have any entry
# 0 hours of 31673 station in Weekday on Spring does not have any entry
# 2 hours of 31673 station in Weekday on Fall does not have any entry
# 0 hours of 31673 station in Weekday on Winter does not have any entry
# 3 hours of 31407 station in Weekday on Summer does not have any entry
# 3 hours of 31407 station in Weekday on Spring does not have any entry
# 3 hours of 31407 station in Weekday on Fall does not have any entry
# 4 hours of 31407 station in Weekday on Winter does not have any entry
# 2 hours of 31333 station in Weekday on Summer does not have any entry
# 0 hours of 31333 station in Weekday on Spring does not have any entry
# 1 hours of 31333 station in Weekday on Fall does not have any entry
# 0 hours of 31333 station in Weekday on Winter does not have any entry
# 4 hours of 31514 station in Weekday on Summer does not have any entry
# 3 hours of 31514 station in Weekday on Spring does not have any entry
# 5 hours of 31514 station in Weekday on Fall does not have any entry
# 1 hours of 31514 station in Weekday on Winter does not have any entry
# 4 hours of 31414 station in Weekday on Summer does not have any entry
# 2 hours of 31414 station in Weekday on Spring does not have any entry
# 0 hours of 31414 station in Weekday on Fall does not have any entry
# 1 hours of 31414 station in Weekday on Winter does not have any entry
# 4 hours of 31523 station in Weekday on Summer does not have any entry
# 5 hours of 31523 station in Weekday on Spring does not have any entry
# 3 hours of 31523 station in Weekday on Fall does not have any entry
# 1 hours of 31523 station in Weekday on Winter does not have any entry
# 3 hours of 31626 station in Weekday on Summer does not have any entry
# 4 hours of 31626 station in Weekday on Spring does not have any entry
# 2 hours of 31626 station in Weekday on Fall does not have any entry
# 3 hours of 31626 station in Weekday on Winter does not have any entry
# 3 hours of 31316 station in Weekday on Summer does not have any entry
# 0 hours of 31316 station in Weekday on Spring does not have any entry
# 0 hours of 31316 station in Weekday on Fall does not have any entry
# 0 hours of 31316 station in Weekday on Winter does not have any entry
# 2 hours of 30200 station in Weekday on Summer does not have any entry
# 2 hours of 30200 station in Weekday on Spring does not have any entry
# 0 hours of 30200 station in Weekday on Fall does not have any entry
# 0 hours of 30200 station in Weekday on Winter does not have any entry
# 4 hours of 31658 station in Weekday on Summer does not have any entry
# 2 hours of 31658 station in Weekday on Spring does not have any entry
# 1 hours of 31658 station in Weekday on Fall does not have any entry
# 0 hours of 31658 station in Weekday on Winter does not have any entry
# 3 hours of 31534 station in Weekday on Summer does not have any entry
# 3 hours of 31534 station in Weekday on Spring does not have any entry
# 2 hours of 31534 station in Weekday on Fall does not have any entry
# 1 hours of 31534 station in Weekday on Winter does not have any entry
# 5 hours of 31612 station in Weekday on Summer does not have any entry
# 3 hours of 31612 station in Weekday on Spring does not have any entry
# 4 hours of 31612 station in Weekday on Fall does not have any entry
# 3 hours of 31612 station in Weekday on Winter does not have any entry
# 3 hours of 31423 station in Weekday on Summer does not have any entry
# 1 hours of 31423 station in Weekday on Spring does not have any entry
# 2 hours of 31423 station in Weekday on Fall does not have any entry
# 0 hours of 31423 station in Weekday on Winter does not have any entry
# 3 hours of 31218 station in Weekday on Summer does not have any entry
# 1 hours of 31218 station in Weekday on Spring does not have any entry
# 4 hours of 31218 station in Weekday on Fall does not have any entry
# 0 hours of 31218 station in Weekday on Winter does not have any entry
# 6 hours of 31647 station in Weekday on Summer does not have any entry
# 3 hours of 31647 station in Weekday on Spring does not have any entry
# 4 hours of 31647 station in Weekday on Fall does not have any entry
# 3 hours of 31647 station in Weekday on Winter does not have any entry
# 1 hours of 31508 station in Weekday on Summer does not have any entry
# 3 hours of 31508 station in Weekday on Spring does not have any entry
# 3 hours of 31508 station in Weekday on Fall does not have any entry
# 2 hours of 31508 station in Weekday on Winter does not have any entry
# 4 hours of 31305 station in Weekday on Summer does not have any entry
# 4 hours of 31305 station in Weekday on Spring does not have any entry
# 4 hours of 31305 station in Weekday on Fall does not have any entry
# 3 hours of 31305 station in Weekday on Winter does not have any entry
# 2 hours of 31622 station in Weekday on Spring does not have any entry
# 4 hours of 31622 station in Weekday on Fall does not have any entry
# 2 hours of 31622 station in Weekday on Winter does not have any entry
# 5 hours of 31513 station in Weekday on Summer does not have any entry
# 5 hours of 31513 station in Weekday on Spring does not have any entry
# 3 hours of 31513 station in Weekday on Winter does not have any entry
# 2 hours of 31507 station in Weekday on Summer does not have any entry
# 0 hours of 31507 station in Weekday on Spring does not have any entry
# 2 hours of 31507 station in Weekday on Fall does not have any entry
# 0 hours of 31507 station in Weekday on Winter does not have any entry
# 3 hours of 31663 station in Weekday on Summer does not have any entry
# 3 hours of 31663 station in Weekday on Spring does not have any entry
# 4 hours of 31663 station in Weekday on Fall does not have any entry
# 3 hours of 31663 station in Weekday on Winter does not have any entry
# 5 hours of 31524 station in Weekday on Summer does not have any entry
# 3 hours of 31524 station in Weekday on Spring does not have any entry
# 3 hours of 31524 station in Weekday on Fall does not have any entry
# 4 hours of 31524 station in Weekday on Winter does not have any entry
# 3 hours of 31501 station in Weekday on Summer does not have any entry
# 3 hours of 31501 station in Weekday on Spring does not have any entry
# 3 hours of 31501 station in Weekday on Fall does not have any entry
# 0 hours of 31501 station in Weekday on Winter does not have any entry
# 4 hours of 31318 station in Weekday on Summer does not have any entry
# 3 hours of 31318 station in Weekday on Spring does not have any entry
# 4 hours of 31318 station in Weekday on Fall does not have any entry
# 1 hours of 31318 station in Weekday on Winter does not have any entry
# 3 hours of 31529 station in Weekday on Spring does not have any entry
# 2 hours of 31529 station in Weekday on Fall does not have any entry
# 1 hours of 31529 station in Weekday on Winter does not have any entry
# 3 hours of 31319 station in Weekday on Summer does not have any entry
# 1 hours of 31319 station in Weekday on Spring does not have any entry
# 2 hours of 31319 station in Weekday on Fall does not have any entry
# 0 hours of 31319 station in Weekday on Winter does not have any entry
# 2 hours of 31630 station in Weekday on Summer does not have any entry
# 1 hours of 31630 station in Weekday on Spring does not have any entry
# 5 hours of 31630 station in Weekday on Fall does not have any entry
# 2 hours of 31630 station in Weekday on Winter does not have any entry
# 2 hours of 31601 station in Weekday on Summer does not have any entry
# ...
# 0 hours of 31656 station in Weekday on Spring does not have any entry
# 3 hours of 31656 station in Weekday on Fall does not have any entry
# 0 hours of 31656 station in Weekday on Winter does not have any entry
# 1 hours of 31411 station in Weekday on Summer does not have any entry
# 0 hours of 31411 station in Weekday on Spring does not have any entry
# 0 hours of 31411 station in Weekday on Fall does not have any entry
# 1 hours of 31411 station in Weekday on Winter does not have any entry
# 3 hours of 31418 station in Weekday on Summer does not have any entry
# 3 hours of 31418 station in Weekday on Spring does not have any entry
# 2 hours of 31418 station in Weekday on Fall does not have any entry
# 2 hours of 31418 station in Weekday on Winter does not have any entry
# 1 hours of 31719 station in Weekday on Summer does not have any entry
# 0 hours of 31719 station in Weekday on Spring does not have any entry
# 2 hours of 31719 station in Weekday on Fall does not have any entry
# 1 hours of 31719 station in Weekday on Winter does not have any entry
# 0 hours of 31425 station in Weekday on Summer does not have any entry
# 1 hours of 31425 station in Weekday on Spring does not have any entry
# 0 hours of 31425 station in Weekday on Fall does not have any entry
# 0 hours of 31425 station in Weekday on Winter does not have any entry
# 4 hours of 31402 station in Weekday on Summer does not have any entry
# 2 hours of 31402 station in Weekday on Spring does not have any entry
# 3 hours of 31402 station in Weekday on Fall does not have any entry
# 0 hours of 31402 station in Weekday on Winter does not have any entry
# 3 hours of 31520 station in Weekday on Summer does not have any entry
# 0 hours of 31520 station in Weekday on Spring does not have any entry
# 3 hours of 31520 station in Weekday on Fall does not have any entry
# 0 hours of 31520 station in Weekday on Winter does not have any entry
# 1 hours of 31403 station in Weekday on Summer does not have any entry
# 1 hours of 31403 station in Weekday on Spring does not have any entry
# 3 hours of 31403 station in Weekday on Fall does not have any entry
# 1 hours of 31403 station in Weekday on Winter does not have any entry
# 2 hours of 31502 station in Weekday on Summer does not have any entry
# 0 hours of 31502 station in Weekday on Spring does not have any entry
# 3 hours of 31502 station in Weekday on Fall does not have any entry
# 0 hours of 31502 station in Weekday on Winter does not have any entry
# 0 hours of 31823 station in Weekday on Summer does not have any entry
# 0 hours of 31823 station in Weekday on Spring does not have any entry
# 0 hours of 31823 station in Weekday on Fall does not have any entry
# 0 hours of 31823 station in Weekday on Winter does not have any entry
# 1 hours of 31708 station in Weekday on Summer does not have any entry
# 0 hours of 31708 station in Weekday on Spring does not have any entry
# 0 hours of 31708 station in Weekday on Fall does not have any entry
# 0 hours of 31708 station in Weekday on Winter does not have any entry
# 4 hours of 31112 station in Weekday on Summer does not have any entry
# 1 hours of 31112 station in Weekday on Spring does not have any entry
# 3 hours of 31112 station in Weekday on Fall does not have any entry
# 0 hours of 31112 station in Weekday on Winter does not have any entry
# 1 hours of 31511 station in Weekday on Spring does not have any entry
# 2 hours of 31511 station in Weekday on Fall does not have any entry
# 4 hours of 31511 station in Weekday on Winter does not have any entry
# 1 hours of 31412 station in Weekday on Summer does not have any entry
# 0 hours of 31412 station in Weekday on Spring does not have any entry
# 2 hours of 31412 station in Weekday on Fall does not have any entry
# 0 hours of 31412 station in Weekday on Winter does not have any entry
# 1 hours of 31528 station in Weekday on Summer does not have any entry
# 0 hours of 31528 station in Weekday on Spring does not have any entry
# 4 hours of 31528 station in Weekday on Fall does not have any entry
# 0 hours of 31528 station in Weekday on Winter does not have any entry
# 0 hours of 31700 station in Weekday on Summer does not have any entry
# 0 hours of 31700 station in Weekday on Spring does not have any entry
# 0 hours of 31700 station in Weekday on Fall does not have any entry
# 0 hours of 31700 station in Weekday on Winter does not have any entry
# 2 hours of 31420 station in Weekday on Summer does not have any entry
# 1 hours of 31420 station in Weekday on Spring does not have any entry
# 2 hours of 31420 station in Weekday on Fall does not have any entry
# 1 hours of 31420 station in Weekday on Winter does not have any entry
# 0 hours of 31530 station in Weekday on Summer does not have any entry
# 2 hours of 31530 station in Weekday on Spring does not have any entry
# 4 hours of 31530 station in Weekday on Fall does not have any entry
# 2 hours of 31530 station in Weekday on Winter does not have any entry
# 0 hours of 31803 station in Weekday on Summer does not have any entry
# 1 hours of 31803 station in Weekday on Spring does not have any entry
# 0 hours of 31803 station in Weekday on Fall does not have any entry
# 0 hours of 31803 station in Weekday on Winter does not have any entry
# 2 hours of 31422 station in Weekday on Summer does not have any entry
# 0 hours of 31422 station in Weekday on Spring does not have any entry
# 0 hours of 31422 station in Weekday on Fall does not have any entry
# 0 hours of 31422 station in Weekday on Winter does not have any entry
# 0 hours of 31814 station in Weekday on Summer does not have any entry
# 0 hours of 31814 station in Weekday on Spring does not have any entry
# 0 hours of 31814 station in Weekday on Fall does not have any entry
# 0 hours of 31814 station in Weekday on Winter does not have any entry
# 0 hours of 31817 station in Weekday on Summer does not have any entry
# 0 hours of 31817 station in Weekday on Spring does not have any entry
# 1 hours of 31817 station in Weekday on Fall does not have any entry
# 0 hours of 31817 station in Weekday on Winter does not have any entry
# 1 hours of 31541 station in Weekday on Summer does not have any entry
# 0 hours of 31541 station in Weekday on Spring does not have any entry
# 0 hours of 31541 station in Weekday on Fall does not have any entry
# 0 hours of 31541 station in Weekday on Winter does not have any entry
# 0 hours of 31542 station in Weekday on Summer does not have any entry
# 0 hours of 31542 station in Weekday on Spring does not have any entry
# 0 hours of 31542 station in Weekday on Fall does not have any entry
# 0 hours of 31542 station in Weekday on Winter does not have any entry
# 2 hours of 31424 station in Weekday on Summer does not have any entry
# 3 hours of 31424 station in Weekday on Spring does not have any entry
# 3 hours of 31424 station in Weekday on Fall does not have any entry
# 0 hours of 31424 station in Weekday on Winter does not have any entry
# 4 hours of 31315 station in Weekday on Summer does not have any entry
# 0 hours of 31315 station in Weekday on Spring does not have any entry
# 4 hours of 31315 station in Weekday on Fall does not have any entry
# 0 hours of 31315 station in Weekday on Winter does not have any entry
# 0 hours of 31818 station in Weekday on Summer does not have any entry
# 3 hours of 31818 station in Weekday on Spring does not have any entry
# 1 hours of 31818 station in Weekday on Fall does not have any entry
# 0 hours of 31818 station in Weekday on Winter does not have any entry
# 0 hours of 31820 station in Weekday on Summer does not have any entry
# 1 hours of 31820 station in Weekday on Spring does not have any entry
# 0 hours of 31820 station in Weekday on Fall does not have any entry
# 0 hours of 31820 station in Weekday on Winter does not have any entry
# 0 hours of 31800 station in Weekday on Summer does not have any entry
# 1 hours of 31800 station in Weekday on Spring does not have any entry
# 0 hours of 31800 station in Weekday on Fall does not have any entry
# 0 hours of 31800 station in Weekday on Winter does not have any entry
# 2 hours of 31416 station in Weekday on Summer does not have any entry
# 1 hours of 31416 station in Weekday on Spring does not have any entry
# 0 hours of 31416 station in Weekday on Fall does not have any entry
# 0 hours of 31416 station in Weekday on Winter does not have any entry
# 2 hours of 31702 station in Weekday on Summer does not have any entry
# 0 hours of 31702 station in Weekday on Spring does not have any entry
# 0 hours of 31702 station in Weekday on Fall does not have any entry
# 0 hours of 31702 station in Weekday on Winter does not have any entry
# 4 hours of 31510 station in Weekday on Summer does not have any entry
# 0 hours of 31510 station in Weekday on Spring does not have any entry
# 0 hours of 31510 station in Weekday on Fall does not have any entry
# 0 hours of 31510 station in Weekday on Winter does not have any entry
# 4 hours of 31703 station in Weekday on Summer does not have any entry
# 0 hours of 31703 station in Weekday on Spring does not have any entry
# 1 hours of 31703 station in Weekday on Fall does not have any entry
# 0 hours of 31703 station in Weekday on Winter does not have any entry
# 1 hours of 31802 station in Weekday on Summer does not have any entry
# 0 hours of 31802 station in Weekday on Spring does not have any entry
# 0 hours of 31802 station in Weekday on Fall does not have any entry
# 0 hours of 31802 station in Weekday on Winter does not have any entry
# 1 hours of 31322 station in Weekday on Summer does not have any entry
# 2 hours of 31322 station in Weekday on Spring does not have any entry
# 1 hours of 31322 station in Weekday on Fall does not have any entry
# 0 hours of 31322 station in Weekday on Winter does not have any entry
# 0 hours of 31822 station in Weekday on Summer does not have any entry
# 0 hours of 31822 station in Weekday on Spring does not have any entry
# 2 hours of 31822 station in Weekday on Fall does not have any entry
# 0 hours of 31822 station in Weekday on Winter does not have any entry
# 1 hours of 31805 station in Weekday on Summer does not have any entry
# 0 hours of 31805 station in Weekday on Spring does not have any entry
# 0 hours of 31805 station in Weekday on Fall does not have any entry
# 0 hours of 31805 station in Weekday on Winter does not have any entry
# 0 hours of 31706 station in Weekday on Summer does not have any entry
# 0 hours of 31706 station in Weekday on Spring does not have any entry
# 0 hours of 31706 station in Weekday on Fall does not have any entry
# 0 hours of 31706 station in Weekday on Winter does not have any entry
# 0 hours of 31701 station in Weekday on Summer does not have any entry
# 0 hours of 31701 station in Weekday on Spring does not have any entry
# 0 hours of 31701 station in Weekday on Fall does not have any entry
# 0 hours of 31701 station in Weekday on Winter does not have any entry
# 0 hours of 31717 station in Weekday on Summer does not have any entry
# 0 hours of 31717 station in Weekday on Spring does not have any entry
# 0 hours of 31717 station in Weekday on Fall does not have any entry
# 0 hours of 31717 station in Weekday on Winter does not have any entry
# 2 hours of 31824 station in Weekday on Summer does not have any entry
# 0 hours of 31824 station in Weekday on Spring does not have any entry
# 0 hours of 31824 station in Weekday on Fall does not have any entry
# 0 hours of 31824 station in Weekday on Winter does not have any entry
# 1 hours of 31807 station in Weekday on Summer does not have any entry
# 0 hours of 31807 station in Weekday on Spring does not have any entry
# 0 hours of 31807 station in Weekday on Fall does not have any entry
# 0 hours of 31807 station in Weekday on Winter does not have any entry
# 0 hours of 31724 station in Weekday on Summer does not have any entry
# 0 hours of 31724 station in Weekday on Spring does not have any entry
# 0 hours of 31724 station in Weekday on Fall does not have any entry
# 0 hours of 31724 station in Weekday on Winter does not have any entry
# 1 hours of 31721 station in Weekday on Summer does not have any entry
# 0 hours of 31721 station in Weekday on Spring does not have any entry
# 0 hours of 31721 station in Weekday on Fall does not have any entry
# 0 hours of 31721 station in Weekday on Winter does not have any entry
# 0 hours of 31716 station in Weekday on Summer does not have any entry
# 0 hours of 31716 station in Weekday on Spring does not have any entry
# 0 hours of 31716 station in Weekday on Fall does not have any entry
# 1 hours of 31716 station in Weekday on Winter does not have any entry
# 0 hours of 31710 station in Weekday on Summer does not have any entry
# 0 hours of 31710 station in Weekday on Spring does not have any entry
# 0 hours of 31710 station in Weekday on Fall does not have any entry
# 0 hours of 31710 station in Weekday on Winter does not have any entry
# 0 hours of 31331 station in Weekday on Summer does not have any entry
# 0 hours of 31331 station in Weekday on Spring does not have any entry
# 0 hours of 31331 station in Weekday on Fall does not have any entry
# 0 hours of 31331 station in Weekday on Winter does not have any entry
# 0 hours of 31521 station in Weekday on Summer does not have any entry
# 1 hours of 31521 station in Weekday on Spring does not have any entry
# 2 hours of 31521 station in Weekday on Fall does not have any entry
# 0 hours of 31521 station in Weekday on Winter does not have any entry
# 0 hours of 31704 station in Weekday on Summer does not have any entry
# 0 hours of 31704 station in Weekday on Spring does not have any entry
# 0 hours of 31704 station in Weekday on Fall does not have any entry
# 0 hours of 31704 station in Weekday on Winter does not have any entry
# 1 hours of 31826 station in Weekday on Summer does not have any entry
# 0 hours of 31826 station in Weekday on Spring does not have any entry
# 0 hours of 31826 station in Weekday on Fall does not have any entry
# 0 hours of 31826 station in Weekday on Winter does not have any entry
# 0 hours of 31812 station in Weekday on Summer does not have any entry
# 0 hours of 31812 station in Weekday on Spring does not have any entry
# 0 hours of 31812 station in Weekday on Fall does not have any entry
# 0 hours of 31812 station in Weekday on Winter does not have any entry
# 0 hours of 31390 station in Weekday on Summer does not have any entry
# 0 hours of 31390 station in Weekday on Spring does not have any entry
# 0 hours of 31390 station in Weekday on Fall does not have any entry
# 0 hours of 31390 station in Weekday on Winter does not have any entry
# 0 hours of 31813 station in Weekday on Summer does not have any entry
# 0 hours of 31813 station in Weekday on Spring does not have any entry
# 0 hours of 31813 station in Weekday on Fall does not have any entry
# 0 hours of 31813 station in Weekday on Winter does not have any entry
# 0 hours of 31713 station in Weekday on Summer does not have any entry
# 0 hours of 31713 station in Weekday on Spring does not have any entry
# 0 hours of 31713 station in Weekday on Fall does not have any entry
# 0 hours of 31713 station in Weekday on Winter does not have any entry
# 0 hours of 31538 station in Weekday on Summer does not have any entry
# 0 hours of 31538 station in Weekday on Spring does not have any entry
# 0 hours of 31538 station in Weekday on Fall does not have any entry
# 0 hours of 31538 station in Weekday on Winter does not have any entry
# 0 hours of 31714 station in Weekday on Summer does not have any entry
# 0 hours of 31714 station in Weekday on Spring does not have any entry
# 0 hours of 31714 station in Weekday on Fall does not have any entry
# 0 hours of 31714 station in Weekday on Winter does not have any entry
# 0 hours of 31804 station in Weekday on Summer does not have any entry
# 0 hours of 31804 station in Weekday on Spring does not have any entry
# 0 hours of 31804 station in Weekday on Fall does not have any entry
# 0 hours of 31804 station in Weekday on Winter does not have any entry
# 0 hours of 31723 station in Weekday on Summer does not have any entry
# 0 hours of 31723 station in Weekday on Spring does not have any entry
# 0 hours of 31723 station in Weekday on Fall does not have any entry
# 0 hours of 31723 station in Weekday on Winter does not have any entry

# %%
len(Seasonal_Hour_DF.StationID.unique())
# Out:
# 352

# %%
Seasonal_Hour_DF["Deperture Count"] = Seasonal_Hour_DF["Deperture Count"].astype(int)
Seasonal_Hour_DF["Arrival Count"] = Seasonal_Hour_DF["Arrival Count"].astype(int)

# %%
Seasonal_Hour_DF
# Out:
#    Hour_(Starting) StationID  Season Day_Type  Deperture Count  Arrival Count
# 0                0     31114  Summer  Weekday               67             33
# 0                1     31114  Summer  Weekday               44             12
# 0                2     31114  Summer  Weekday               12              4
# 0                3     31114  Summer  Weekday                4              2
# 0                4     31114  Summer  Weekday                3              1
# ..             ...       ...     ...      ...              ...            ...
# 0                0     31716  Winter  Weekend                1              2
# 0                0     31521  Spring  Weekend                1              1
# 0                0     31521    Fall  Weekend                1              9
# 0                1     31521    Fall  Weekend                1              2
# 0                0     31826  Summer  Weekend                1              1
#
# [22817 rows x 6 columns]

# %%
Seasonal_Hour_DF["Day_Type"].unique()
# Out:
# array(['Weekday', 'Weekend'], dtype=object)

# %%
Seasonal_Hour_DF.to_csv("62For_Seasonal_Hourly_Dynamics.csv")

# %%
# Seasonal_Hour_DF.to_csv("63_1For_Seasonal_Hourly_DayType_Dynamics.csv")
